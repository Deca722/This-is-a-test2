# %% [markdown]
# ### 删除缺失数据

# %% [markdown]
# #### 对整列缺失值进行填充

# %% [markdown]
# ##### df['']=''

# %% [markdown]
# #### 对某个缺失值进行填充

# %% [markdown]
# ##### df.loc['传入索引','传入列名']=新值

# %% [markdown]
# #### 自动找到缺失值进行填充可以用fillna方法

# %% [markdown]
# #### 自动删除存在缺失值的行用dropna方法
# #### 给dropna传入subset参数可以指定检查存在缺失值的范围

# %% [markdown]
# ### 删除重复数据

# %% [markdown]
# #### 可以用drop_duplicated方法

# %% [markdown]
# #### 一般是删除后出现的值但是如果使用keep='last'则会保留后面的删除前面的

# %% [markdown]
# ### 对值进行替换

# %% [markdown]
# #### 用replace方法

# %% [markdown]
# ### 对值的类型进行转换

# %% [markdown]
# #### 可以用astype方法传入要转化成的类型

# %% [markdown]
# #### 特别的，s1.astype('category')
# #### 这是pandas库中特殊的类型
