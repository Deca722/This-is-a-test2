# %%
import numpy as np

# %%
arr1 = np.array([1,2,3])
arr1
# Out:
# array([1, 2, 3])

# %%
arr2 = np.array([[1,2,3],[5,6,7]])
arr2
# Out:
# array([[1, 2, 3],
#        [5, 6, 7]])

# %% [markdown]
# ### 返回数组维度

# %%
print(arr1.ndim)
print(arr2.ndim)
# Out:
# 1
# 2

# %% [markdown]
# ### 返回数组各维度的元素个数

# %%
print(arr1.shape)
print(arr2.shape)
# Out:
# (3,)
# (2, 3)

# %% [markdown]
# ### 返回数组元素的总个数

# %%
print(arr1.size)
print(arr2.size)
# Out:
# 3
# 6

# %% [markdown]
# ### 返回数组元素的类型

# %%
print(arr1.dtype)
# Out:
# int64

# %%
np.zeros(3)
# Out:
# array([0., 0., 0.])

# %%
np.ones(5)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
np.arange(5,9,0.2)
# Out:
# array([5. , 5.2, 5.4, 5.6, 5.8, 6. , 6.2, 6.4, 6.6, 6.8, 7. , 7.2, 7.4,
#        7.6, 7.8, 8. , 8.2, 8.4, 8.6, 8.8])

# %%
print("Aa?")
# Out:
# Aa?

# %%
print("Aa?")
# Out:
# Aa?

# %%
print("Aa?")
# Out:
# Aa?

# %% [markdown]
# #

# %% [markdown]
# # 最大的标题

# %% [markdown]
# ###### 小的

# %% [markdown]
# 公式:
# $$x^2 + y^2 = 1$$

# %%
arr3 = np.zeros(3)

# %%
arr4 = np.concatenate([arr1,arr3])

# %%
print(np.sort(arr4))
# Out:
# [0. 0. 0. 1. 2. 3.]

# %%
print(arr4[-6])
# Out:
# 1.0

# %%
print(arr4[1:4])
# Out:
# [2. 3. 0.]

# %%
import pandas as pd

# %%
s1  = pd.Series([5,17,3,26,31],
         index=["a","d","b","c","e"])
s1
# Out:
# a     5
# d    17
# b     3
# c    26
# e    31
# dtype: int64

# %%
s1.values
# Out:
# array([ 5, 17,  3, 26, 31])

# %%
s1.index
# Out:
# Index(['a', 'd', 'b', 'c', 'e'], dtype='object')

# %%
s1["b"]
# Out:
# np.int64(3)

# %%
s1[1:3]
# Out:
# d    17
# b     3
# dtype: int64

# %%
s1["d":"c"]
# Out:
# d    17
# b     3
# c    26
# dtype: int64

# %%
s1[["a","e","c"]]
# Out:
# a     5
# e    31
# c    26
# dtype: int64

# %%
s1.iloc[1:3]
# Out:
# d    17
# b     3
# dtype: int64
